# %%
from ipywidgets import widgets, Layout, HTML
from IPython.display import display

output = widgets.Output(layout=Layout(width='0px', height='0px'))
display(output)

# %run urlUpdate.py

urlUpdate('?test=2', output)
# Out:
# Output(layout=Layout(height='0px', width='0px'))
