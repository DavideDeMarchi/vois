# %%
# FULLSCREEN EXAMPLE
import ipyvuetify as v

import settings
settings.dark_mode      = False
settings.color_second   = '#d8e7f5'
settings.color_first    = '#68aad2'
settings.button_rounded = False

# %run app.py

# Click on a tab of the title
def on_click_tab(arg):
    g_app.snackbar(arg)

# Click on the credits text
def on_click_credits():
    g_app.snackbar('CREDITS')
    
# Click on the logo
def on_click_logo():
    g_app.snackbar('LOGO')

# Click on the footer buttons
def on_click_footer(arg):
    g_app.snackbar(arg)
    
# Click on the footer minipanel
def on_click_minipanel(index):
    g_app.snackbar(str(index))
    
    
g_app = app(title='Energy consumption dashboard',
            titlecredits='Created by Unit I.3',
            titlewidth='30%',
            totalheight=385,
            dark=True,
            backgroundimageurl='https://picsum.photos/id/1050/1920/1080?grayscale',
            #titletabs=[],
            sidepanelwidth=400,
            sidepaneltext="Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.",
            sidepanelcontent=[v.Icon(class_='pa-0 ma-0 ml-2', children=['mdi-help'])],
            sidepaneldark=True,
            sidepanelbackdark=True,
            #minipanelicons=['fa-truck', 'mdi-heart', 'mdi-magnify'],
            #minipaneltooltips=['Function 1', 'Function 2', 'Function 3'],
            #minipanellarge=False,
            #minipanelopen=False,
            #minipanelbuttoncolor='black',
            #minipaneliconscolor='#010101',
            footercolor='#888888',
            footerdark=True,
            footerbuttons=[],
            footerheight=38,
            onclickminipanel=on_click_minipanel,
            onclicktab=on_click_tab,
            onclickcredits=on_click_credits,
            onclicklogo=on_click_logo,
            onclickfooter=on_click_footer,
            fullscreen=True)

# %run datePicker.py
datemin = datePicker(date='2022-09-12', label='Min date:', offset_x=False, offset_y=True)
with g_app.outcontent:
    display(datemin.draw())

g_app.show()

# %%
g_app.outcontent.layout.height

# %%
# APP EXAMPLE WITH SVG AS TITLE AND TITLE BACKGROUND IMAGE IN BASE64
import ipyvuetify as v

import settings
settings.dark_mode      = False
settings.color_first    = '#f4aa0d'
settings.color_second   = '#2a2a2a'
settings.button_rounded = False

# %run app.py

# Click on a tab of the title
def on_click_tab(arg):
    g_app.snackbar(arg)

# Click on the credits text
def on_click_credits():
    g_app.snackbar('CREDITS')
    
# Click on the logo
def on_click_logo():
    g_app.snackbar('LOGO')

# Click on the footer buttons
def on_click_footer(arg):
    g_app.snackbar(arg)
    
# Click on the footer minipanel
def on_click_minipanel(index):
    g_app.snackbar(str(index))


# Example of a text with shadow    
titlesvg = '''
<svg width="350" height="75" viewBox="0 0 350 75">
  <g style="overflow:hidden; text-anchor: middle; font-size:48; font-weight: bold; font-family: Arial, Helvetica, sans-serif">
    <defs>
      <filter id="shadow" x="-20%" y="-20%" width="140%" height="140%">
        <feGaussianBlur stdDeviation="2 2" result="shadow"/>
        <feOffset dx="6" dy="6"/>
      </filter>
    </defs>
    <text style="filter: url(#shadow); fill: grey" x="175" y="58">Fancy title</text>
    <text x="175" y="58" style="fill: black">Fancy title</text>
  </g>
</svg>
'''

    
# See https://www.base64-image.de/ for conversion of images to base64 string
# See https://maketext.io/         for creating fancy text in SVG format
# See https://www.freepik.com/free-photos-vectors/technology           for tech background images
#     https://www.freepik.com/free-photos-vectors/abstract-background  for abstract background images
g_app = app(title='Prova',
            titlesvg=titlesvg,
            #titlesvgclass='pa-0 ma-0 ml-1',
            titlecredits='Created by Unit I.3',
            titlewidth='60%',
            titleheight='6vh',  # NOT WORKING!!!
            #titleheight=68,
            totalheight='60vh',
            dark=True,
            backgroundimageurl='data:image/png;base64,...',
            sidepanelwidth=0,
            sidepaneltext="Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.",
            sidepanelcontent=[v.Icon(class_='pa-0 ma-0 ml-2', children=['mdi-help'])],
            sidepaneldark=True,
            sidepanelbackdark=False,
            #minipanelicons=['fa-truck', 'mdi-heart', 'mdi-magnify'],
            #minipaneltooltips=['Function 1', 'Function 2', 'Function 3'],
            #minipanellarge=False,
            #minipanelopen=False,
            #minipanelbuttoncolor='black',
            #minipaneliconscolor='#010101',
            footercolor=settings.color_first,
            footerdark=False,
            footerbuttons=[],
            footerheight='4vh',
            onclickminipanel=on_click_minipanel,
            onclicktab=on_click_tab,
            onclickcredits=on_click_credits,
            onclicklogo=on_click_logo,
            onclickfooter=on_click_footer,
            fullscreen=False)

'''
# %run datePicker.py
datemin = datePicker(date='2022-09-12', label='Min date:', offset_x=False, offset_y=True)
with g_app.outcontent:
    display(datemin.draw())

g_app.contentBackground('data:image/png;base64,...')

#out = g_app.contentAddPanel("30vw", "18vh", "20vw", "4vh", '1px solid grey', '#ffffff55', title='Test')  # Semi-Transparent!!!

from vois import svgUtils
with out:
    display(svgUtils.SmallCircle('Edible', '53.7%', 53.7, forecolor=settings.color_first, backcolor='white', textcolor='black', dimension=170.0))
'''
        
g_app.show()

# %%
g_app.outcontent.layout.border = '1px solid lightgrey'

# %%
g_app.outcontent.layout.border = ''

# %%
# NON FULLSCREEN EXAMPLE
import ipyvuetify as v

import settings
settings.dark_mode = True
settings.color_second = '#68aad2'
settings.color_first  = '#1c4056'
settings.button_rounded = False

# Set the dark theme for ipyvuetify!!!
v.theme.dark = True


# %run app.py

# Click on a tab of the title
def on_click_tab(arg):
    g_app.snackbar(arg)

# Click on the credits text
def on_click_credits():
    g_app.snackbar('CREDITS')
    
# Click on the logo
def on_click_logo():
    g_app.snackbar('LOGO')

# Click on the footer buttons
def on_click_footer(arg):
    g_app.snackbar(arg)
    
# Click on the footer minipanel
def on_click_minipanel(index):
    g_app.snackbar(str(index))

    
g_view = 0
g_maintabs = ['Chart', 'Table', 'Static Map', 'Dynamic Map']

g_app = app(title='Energy consumption example dashboard',
                titlecredits='Created by Unit I.3',
                #titleheight='8vh', # NOT WORKING!
                titleheight=68,
                titlewidth='45%',
                footercolor='#1c4056',
                titletabs=g_maintabs,
                titletabsstile='font-weight: 700; font-size: 17px;',
                titletabsactive=g_view,
                titletabsactiveparameter='view',
                titletabscolor='#60b3e8',
                dark=True,
                footerdark=True,
                backgroundimageurl='https://picsum.photos/id/8/1920/1080',
                #backcolor='#1c4056',
                sidepaneltitle='Help',
                sidepaneltext="Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.",
                sidepanelcontent=[v.Icon(class_='pa-0 ma-0 ml-2', children=['mdi-help'])],
                minipanelicons=['mdi-chart-bar', 'mdi-table-large', 'mdi-map-legend', 'mdi-file-chart-outline'], minipaneltooltips=['Download Chart', 'Download Table', 'Download Map', 'Generate Report in Word .docx format'],
                minipanellarge=True, minipanelopen=False, minipanelbuttoncolor='white',
                onclickminipanel=on_click_minipanel,
                onclicktab=on_click_tab,
                onclickcredits=on_click_credits,
                onclicklogo=on_click_logo,
                onclickfooter=on_click_footer)

g_app.show()

# %% [markdown]
# #### Examples of communication with the users through the app instance (using the internal g_app.outdialogs Output widget!)

# %%
g_app.snackbar(title='Message', text='Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.')

# %%
g_app.dialogMessage(title='Message', width=800, text='Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.')

# %%
g_app.dialogYesNo(title='Question', text='Confirm removal of the selected file?')

# %%
import switch
s = switch.switch(True, 'PNG format')
g_app.dialogGeneric(title='Settings', text='Please select the format for download:', content=[s.draw()])

# %%
g_app.dialogWaitOpen(text='Please wait for processing to terminate...')

# %%
g_app.dialogWaitClose()

# %% [markdown]
# #### Example of fab button displayed through the app (using the internal g_app.outfabs Output widget!)

# %%
fab = g_app.fab(left='70%', top='150px', items=['aaa bbb ccc', 'ddd eee fff', 'ggg hhh iii'], menumode=True)

# %%
fab.close()

# %% [markdown]
# #### Downloads of text and binary file through the app instance (using the internal g_app.outdownload Output widget!)

# %%
g_app.downloadText('aaa bbb ccc')

# %%
g_app.downloadBytes(b'ajgh lkjhl ')

# %% [markdown]
# #### Read parameter passed on the URL

# %%
g_app.urlParameter('activetab')

# %% [markdown]
# #### Update the URL

# %%
g_app.urlUpdate('?test=3')

# %% [markdown]
# #### Open a URL in another tab through the app (using the internal g_app.outurlopen Output widget!)

# %%
g_app.urlOpen('https://www.google.com')
